# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusbuttow/LLMs-com-bancos-de-dados-vetoriais/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from getpass import getpass

GROQ_API = getpass("Digite sua chave GROQ_API: ")
print("Chave carregada com sucesso!")
# Out:
# Digite sua chave GROQ_API: ··········
# Chave carregada com sucesso!

# %%
# !pip install -q llama-index llama-index-llms-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 87.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.3/303.3 kB 21.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.5/323.5 kB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.4/144.4 kB 9.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.

# %%
from llama_index.llms.groq import Groq

# %%
llm = Groq(model="llama-3.1-8b-instant", api_key=GROQ_API)

# %%
from llama_index.core.chat_engine import SimpleChatEngine

# %%
chat_engine = SimpleChatEngine.from_defaults(llm=llm)

# %%
chat_engine.chat_repl()
# Out:
# ===== Entering Chat REPL =====
# Type "exit" to exit.
#
# Human: exit

# %%
llm.complete('consegue me ajudar com duvidas literarias')
# Out:
# CompletionResponse(text='Claro, estou aqui para ajudar com suas dúvidas literárias. Qual é a sua pergunta ou qual obra literária você gostaria de discutir? Estou preparado para ajudar com:\n\n- Análise de personagens\n- Explicação de conceitos literários (como simbolismo, metáfora, etc.)\n- Discussão de temas e motivações\n- Identificação de estilos e movimentos literários\n- História da literatura\n- E muito mais!\n\nQual é a sua dúvida ou qual obra você gostaria de explorar?', additional_kwargs={'prompt_tokens': 46, 'completion_tokens': 129, 'total_tokens': 175}, raw=ChatCompletion(id='chatcmpl-3b0e1220-f5d4-4cc9-a344-ca0e7d01d91d', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Claro, estou aqui para ajudar com suas dúvidas literárias. Qual é a sua pergunta ou qual obra literária você gostaria de discutir? Estou preparado para ajudar com:\n\n- Análise de personagens\n- Explicação de conceitos literários (como simbolismo, metáfora, etc.)\n- Discussão de temas e motivações\n- Identificação de estilos e movimentos literários\n- História da literatura\n- E muito mais!\n\nQual é a sua dúvida ou qual obra você gostaria de explorar?', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1759277360, model='llama-3.1-8b-instant', object='chat.completion', service_tier='on_demand', system_fingerprint='fp_50a6be1b6f', usage=CompletionUsage(completion_tokens=129, prompt_tokens=46, total_tokens=175, completion_tokens_details=None, prompt_tokens_details=None, queue_time=0.232286904, prompt_time=0.002423652, completion_time=0.260704159, total_time=0.263127811), usage_breakdown=None, x_groq={'id': 'req_01k6ehm8y7e3h809dxcfad2jbq'}), logprobs=None, delta=None)

# %%
resposta = llm.complete('consegue me ajudar com duvidas literarias').text

# %%
print(resposta)
# Out:
# Claro, estou aqui para ajudar com suas dúvidas literárias. Qual é o seu problema ou qual obra literária você gostaria de discutir? Estou preparado para ajudar com:
#
#  - Análise de personagens
#  - Explicação de temas e símbolos
#  - Discussão de estilos e técnicas literárias
#  - Identificação de alusões e referências culturais
#  - Análise de estrutura e narrativa
#  - E muitas outras coisas!
#
# Qual é a sua pergunta ou qual obra literária você gostaria de discutir?

# %%
duvida_user = "recomende livros de romance"

# %%
resposta = llm.complete(duvida_user).text
print(resposta)
# Out:
# Aqui estão algumas sugestões de livros de romance que você pode gostar:
#
# **Clássicos do Gênero**
#
# 1. "Pride and Prejudice" de Jane Austen: Uma história de amor e família que se desenrola em um ambiente aristocrático do século XIX.
# 2. "Jane Eyre" de Charlotte Brontë: Uma jovem mulher que se apaixona por um homem misterioso e rico, mas enfrenta desafios e obstáculos ao longo do caminho.
# 3. "Wuthering Heights" de Emily Brontë: Uma história de amor e ódio que se desenrola em um ambiente rural do século XIX.
#
# **Romance Contemporâneo**
#
# 1. "A Mulher do Fim do Mundo" de Emily St. John Mandel: Uma história de amor e perda que se desenrola em um mundo pós-apocalíptico.
# 2. "O Diário de uma Garota Louca" de Rainbow Rowell: Uma história de amor e autoconhecimento que se desenrola em um ambiente universitário.
# 3. "A História de Noah" de John Green: Uma história de amor e perda que se desenrola em um ambiente universitário.
#
# **Romance Histórico**
#
# 1. "A Rainha dos Cães" de Philippa Gregory: Uma história de amor e poder que se desenrola em um ambiente medieval.
# 2. "A Dama do Castelo" de Jeanne Kalogridis: Uma história de amor e traição que se desenrola em um ambiente medieval.
# 3. "A Rainha Vermelha" de Philippa Gregory: Uma história de amor e poder que se desenrola em um ambiente medieval.
#
# **Romance Épico**
#
# 1. "A Série de Outlander" de Diana Gabaldon: Uma história de amor e aventura que se desenrola em um ambiente histórico.
# 2. "A Série de The All Souls Trilogy" de Deborah Harkness: Uma história de amor e magia que se desenrola em um ambiente histórico.
# 3. "A Série de The Night Circus" de Erin Morgenstern: Uma história de amor e magia que se desenrola em um ambiente histórico.
#
# Essas são apenas algumas sugestões, mas há muitos outros livros de romance incríveis para você explorar. Qual é o seu gosto?

# %%
import pandas as pd

# %%
df = pd.read_csv('csv/livros_mais_vendidos.csv')

# %%
df
# Out:
#                                                   nome   categoria  \
# 0          É ASSIM QUE COMEÇA (EDIÇÃO DE COLECIONADOR)    Romances
# 1                                           TUDO É RIO    Romances
# 2                      VERITY (EDIÇÃO DE COLECIONADOR)   Suspenses
# 3                                      TÁTICAS DO AMOR    Romances
# 4                                         NEM TE CONTO    Romances
# ..                                                 ...         ...
# 170                                  MEU DIÁRIO MÁGICO  Literatura
# 171  ERA UMA VEZ UM CORAÇÃO PARTIDO (SUCESSO DO TIK...  Literatura
# 172            AS AVENTURAS DE MIKE 3: MUDANDO DE CASA    Infantil
# 173      TURMA DA MÔNICA - BIBLIOTECA DE BOAS MANEIRAS  0 - 3 anos
# 174                              HEARTSTOPPER (VOL. 5)        Teen
#
#                                                sinopse     preco
# 0    Todo final tem um começo. Agora em uma edição ...  R$ 94,90
# 1                                                  NaN  R$ 71,39
# 2    Um casal apaixonado. Uma intrusa. Três mentes ...  R$ 79,90
# 3    Febre no TikTok, comédia romântica narra a ami...  R$ 65,89
# 4    Da autora best seller do \n                   ...  R$ 59,90
# ..                                                 ...       ...
# 170  Agora você pode manter seus segredos a salvo c...  R$ 39,90
# 171  A nova série de Stephanie Garber, aclamada aut...  R$ 76,78
# 172  A continuação do best-seller As aventuras de M...  R$ 61,49
# 173  Obrigada! • Por favor! • Com licença! • Saudaç...  R$ 44,90
# 174  No aguardado quinto volume da série em quadrin...  R$ 87,89
#
# [175 rows x 4 columns]

# %%
prompt = "só recomende livros dessa base de dados"

# %%
for linha in df.values:
  prompt += '\n' + linha[0]

# %%
resposta = llm.complete(prompt + duvida_user).text
print(resposta)
# Out:
# Aqui estão algumas recomendações de livros de romance da lista:
#
# 1. **Tudo é Rio** - Um romance que explora a vida e a paixão de uma jovem mulher em um cenário de beleza natural.
# 2. **Tática do Amor** - Um livro que oferece conselhos e estratégias para conquistar o amor e manter a relação saudável.
# 3. **Nem te Conto** - Um romance que conta a história de amor e perda de uma jovem mulher.
# 4. **O Beijo da Neve** - Um livro que explora a magia do amor e a beleza da natureza.
# 5. **Quarta Asa** - Um romance que conta a história de uma jovem mulher que busca encontrar seu lugar no mundo e seu amor.
# 6. **Véspera** - Um livro que explora a vida e a paixão de uma jovem mulher em um cenário de beleza natural.
# 7. **A Mandíbula de Caim** - Um romance que conta a história de uma jovem mulher que busca encontrar seu lugar no mundo e seu amor.
# 8. **Eu e Esse Meu Coração** - Um livro que explora a vida e a paixão de uma jovem mulher em um cenário de beleza natural.
# 9. **Jantar Secreto** - Um romance que conta a história de uma jovem mulher que busca encontrar seu lugar no mundo e seu amor.
# 10. **Imperfeitos** - Um livro que explora a vida e a paixão de uma jovem mulher em um cenário de beleza natural.
#
# Esses livros são apenas algumas das opções disponíveis na lista. Se você está procurando por algo específico, como um romance de ficção científica ou um livro de mistério, pode ser necessário procurar em outras partes da lista.

# %%
prompt = """
Somente responda em json
Formato resposta em json
[data:{
  "livros": [
    {
      "titulo": "Titulo do livro
      "categoria": "Categoria do livro"
      "Justificativa" "Porque recomenda"
    }
  ]
}]
Só recomende livros dessa base de dados:
"""

# %%
for linha in df.values:
  prompt += f"\n{linha[0]}"

# %%
entrada_user = "recomende livros de romance"

# %%
entrada_user = "Recomende livros de romance"

resposta = llm.complete(prompt=prompt+entrada_user).text
print(resposta)
# Out:
# {
#   "livros": [
#     {
#       "titulo": "TUDO SOBRE O AMOR - NOVAS PERSPECTIVAS",
#       "categoria": "Romance",
#       "justificativa": "Livro que explora as diferentes perspectivas do amor"
#     },
#     {
#       "titulo": "TUDO O QUE EU SEI SOBRE O AMOR",
#       "categoria": "Romance",
#       "justificativa": "Livro que fala sobre o amor e as experiências do autor"
#     },
#     {
#       "titulo": "AMOR & GELATO",
#       "categoria": "Romance",
#       "justificativa": "Livro que combina amor e gelato em uma história romântica"
#     },
#     {
#       "titulo": "ERA UMA VEZ UM CORAÇÃO PARTIDO",
#       "categoria": "Romance",
#       "justificativa": "Livro que fala sobre o amor e a perda"
#     },
#     {
#       "titulo": "CORALINE",
#       "categoria": "Romance",
#       "justificativa": "Livro que fala sobre a busca por amor e aceitação"
#     },
#     {
#       "titulo": "HEARTSTOPPER (VOL. 5)",
#       "categoria": "Romance",
#       "justificativa": "Livro que fala sobre o amor e a amizade"
#     }
#   ]
# }

# %%
import json

# %%
resposta_json = json.loads(resposta)

# %%
titulo = resposta_json['livros'][0]['titulo']
print(titulo)
# Out:
# TUDO SOBRE O AMOR - NOVAS PERSPECTIVAS

# %%
! pip install -q llama-index-embeddings-huggingface

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

# %%
embed_model = HuggingFaceEmbedding(model_name = 'intfloat/multilingual-e5-large')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/201 [00:00<?, ?B/s]

# %%
class ChromaEmbeddingsWrapper:
  def __init__(self, model_name):
        self.model = HuggingFaceEmbedding(model_name=model_name)

  def __call__(self, input):
    return self.model.embed(input)

embed_model_chroma = ChromaEmbeddingsWrapper('intfloat/multilingual-e5-large')

# %%
query_embeded = embed_model.get_text_embedding("Quero livros de romance")

# %%
# !pip install -q llama-index-vector-stores-chroma
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 87.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 72.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.8/510.8 kB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 94.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.2/452.2 kB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.5 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done

# %%
import chromadb

db = chromadb.PersistentClient(path="./chroma_db")
chroma_client = db

collection_name = "meus_documentos"

chroma_collection = chroma_client.get_or_create_collection(name=collection_name, embedding_function=embed_model_chroma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-38562252.py in <cell line: 0>()
#       6 collection_name = "meus_documentos"
#       7
# ----> 8 chroma_collection = chroma_client.get_or_create_collection(name=collection_name, embedding_function=embed_model_chroma)
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/client.py in get_or_create_collection(self, name, configuration, metadata, embedding_function, data_loader)
#     249         persisted_ef_config = model.configuration_json.get("embedding_function")
#     250
# --> 251         validate_embedding_function_conflict_on_get(
#     252             embedding_function, persisted_ef_config
#     253         )
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/collection_configuration.py in validate_embedding_function_conflict_on_get(embedding_function, persisted_ef_config)
#     787     if persisted_ef_config is not None and embedding_function is not None:
#     788         if (
# --> 789             embedding_function.name() != "default"
#     790             and persisted_ef_config.get("name") is not None
#     791             and persisted_ef_config.get("name") != embedding_function.name()
#
# AttributeError: 'ChromaEmbeddingsWrapper' object has no attribute 'name'

# %%
import chromadb

db = chromadb.PersistentClient(path="./chroma_db")
chroma_client = db

collection_name = "meus_documentos"

chroma_collection = chroma_client.get_or_create_collection(name=collection_name, embedding_function=embed_model_chroma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-38562252.py in <cell line: 0>()
#       6 collection_name = "meus_documentos"
#       7
# ----> 8 chroma_collection = chroma_client.get_or_create_collection(name=collection_name, embedding_function=embed_model_chroma)
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/client.py in get_or_create_collection(self, name, configuration, metadata, embedding_function, data_loader)
#     249         persisted_ef_config = model.configuration_json.get("embedding_function")
#     250
# --> 251         validate_embedding_function_conflict_on_get(
#     252             embedding_function, persisted_ef_config
#     253         )
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/collection_configuration.py in validate_embedding_function_conflict_on_get(embedding_function, persisted_ef_config)
#     787     if persisted_ef_config is not None and embedding_function is not None:
#     788         if (
# --> 789             embedding_function.name() != "default"
#     790             and persisted_ef_config.get("name") is not None
#     791             and persisted_ef_config.get("name") != embedding_function.name()
#
# AttributeError: 'ChromaEmbeddingsWrapper' object has no attribute 'name'

# %%
from sentence_transformers import SentenceTransformer

# Modelo de embeddings leve e popular
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
#  -2.89095100e-02  1.23129487e-02  7.19968379e-02 -4.09231856e-02
#  -1.78208090e-02 -9.98095050e-02 -7.84538910e-02  9.42497354e-05
#   1.17218800e-01 -7.29179010e-03 -4.46517952e-02 -3.52507979e-02
#   4.65788469e-02  6.54820502e-02  3.49877984e-03  5.29629886e-02
#   8.50374252e-03  7.57151246e-02  7.23849833e-02 -7.74750113e-02
#  -1.12826027e-01  9.05739237e-03 -2.79027503e-02  3.87922861e-02
#  -9.25837234e-02  6.99149966e-02 -5.77440998e-03  3.05901468e-03
#   2.39702538e-02 -4.19400213e-03 -2.62094475e-02 -2.84517165e-02
#  -3.68393352e-03  6.57394081e-02 -1.25706373e-02 -1.44254481e-02
#   3.63916084e-02 -3.09578273e-02 -3.09121367e-02  4.26819436e-02
#  -2.07718164e-02  2.16054786e-02 -1.88347083e-02 -1.74289490e-08
#   7.55786139e-04 -7.39542246e-02  4.77918200e-02  4.40125205e-02
#   7.20910132e-02 -4.52947728e-02  1.29477633e-03 -3.77268307e-02
#   3.12089324e-02  1.93376895e-02  6.68570353e-03 -3.04760113e-02
#  -1.99092319e-03  5.05065210e-02  4.70637120e-02  6.10050596e-02
#   4.40465324e-02  1.52138323e-02  1.86137166e-02  3.00490297e-03
#   3.78820412e-02 -6.80371076e-02 -3.12998854e-02 -6.56282380e-02
#  -4.91204672e-02  1.99941657e-02  1.67803317e-02  1.74346138e-02
#  -4.48418316e-04 -6.35211021e-02 -1.25546427e-02 -5.70507301e-03
#  -2.60704383e-02 -8.64331797e-02 -1.53295502e-01 -3.90541032e-02
#  -3.72612067e-02 -1.65574607e-02 -3.87872905e-02 -9.29112509e-02
#   7.64382035e-02  6.66209459e-02  3.90155539e-02  4.31589736e-03
#   2.31465157e-02 -4.21344638e-02  5.87436818e-02 -6.16836622e-02
#   2.86165392e-04  5.12226368e-04 -2.03036498e-02 -2.54886318e-03
#   7.47867599e-02  3.76169682e-02  3.85897569e-02 -5.30313179e-02
#   1.45035475e-01 -6.81120262e-04 -1.24489302e-02  1.46678323e-02
#   1.04541155e-02  3.09883021e-02 -2.78324652e-02 -1.08273351e-03]

# %%
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Tokens: ['O', 'Ġg', 'ato', 'Ġest', 'Ã¡', 'Ġno', 'Ġtel', 'h', 'ado']
# IDs dos tokens: [46, 308, 5549, 1556, 6557, 645, 13632, 71, 4533]

# %%
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext

# %%
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storege_context = StorageContext.from_defaults(vector_store=vector_store)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-752890716.py in <cell line: 0>()
# ----> 1 vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
#       2 storege_context = StorageContext.from_defaults(vector_store=vector_store)
#
# NameError: name 'chroma_collection' is not defined

# %%
from llama_index.core import SimpleDirectoryReader

# %%
documents = SimpleDirectoryReader(input_dir="csv").load_data()

# %%
documents
# Out:
# [Document(id_='4b469ad7-0ca8-47c8-bf92-0eec94ddd8ef', embedding=None, metadata={'file_path': '/content/csv/livros_mais_vendidos.csv', 'file_name': 'livros_mais_vendidos.csv', 'file_type': 'text/csv', 'file_size': 215008, 'creation_date': '2025-10-01', 'last_modified_date': '2025-10-01'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="É ASSIM QUE COMEÇA (EDIÇÃO DE COLECIONADOR), Romances, Todo final tem um começo. Agora em uma edição especial de colecionador, com pintura trilateral e exclusiva para o Brasil, conheça a sequência de \n                        É assim que acaba\n                        . Da autora best-seller mundial e fenômeno editorial Colleen Hoover, que já vendeu mais de dois milhões de livros no país.\n                    \n                \n                \n                \xa0\n                \n                Lily Bloom continua administrado uma floricultura. Seu ex-marido abusivo, Ryle Kincaid, ainda é um cirurgião. Mas agora os dois estão oficialmente divorciados e dividem a guarda da filha, Emerson.\n                \n                Quando Lily esbarra em Atlas — com quem não fala há quase dois anos —, é inegável que os dois podem retomar o relacionamento da adolescência, já que ele também está solteiro e parece corresponder seus sentimentos. Mas apesar de estar divorciada, Lily não está exatamente livre de Ryle. Culpando Atlas pelo fim de seu casamento, o ex-marido não está nada disposto a aceitar o novo relacionamento de Lily, principalmente no que diz respeito a Atlas, o último homem que aceitaria ver perto de sua filha e da ex-esposa.\n                \n                \n                    Alternando entre as perspectivas de Altas e Lily, \n                    É assim que começa\n                     segue o epílogo do fenômeno editorial \n                    É assim que acaba\n                    . Revelando mais sobre o passado de Atlas e acompanhando Lily abraçar uma segunda chance no amor enquanto lida com um ex-marido ciumento, \n                    É assim que começa\n                     prova que ninguém entrega uma leitura mais emocionante do que Colleen Hoover.\n                \n                \n                \xa0\n                \n                \n                    “Em uma história permeada de tensão com lampejos de esperança, Hoover captura perfeitamente as dores de um coração partido e a felicidade de começar de novo.” — \n                    Kirkus Review, R$ 94,90\nTUDO É RIO, Romances, nan, R$ 71,39\nVERITY (EDIÇÃO DE COLECIONADOR), Suspenses, Um casal apaixonado. Uma intrusa. Três mentes doentias. Agora em uma edição especial de colecionador com capítulo extra inédito, conheça o thriller de estreia de Colleen Hoover, que se tornou um fenômeno editorial e best-seller mundial.\n                \n                \n                \xa0\n                \n                Verity Crawford é a autora best-seller por trás de uma série de sucesso. Ela está no auge de sua carreira, aclamada pela crítica e pelo público, no entanto, um súbito e terrível acidente acaba interrompendo suas atividades, deixando-a sem condições de concluir a história... E é nessa complexa circunstância que surge Lowen Ashleigh, uma escritora à beira da falência convidada a escrever, sob um pseudônimo, os três livros restantes da já consolidada série.\n                \n                Para que consiga entender melhor o processo criativo de Verity com relação aos livros publicados e, ainda, tentar descobrir seus possíveis planos para os próximos, Lowen decide passar alguns dias na casa dos Crawford, imersa no caótico escritório de Verity - e, lá, encontra uma  ...

# %%
from llama_index.core import VectorStoreIndex

# %%
index = VectorStoreIndex.from_documents(documents, storage_context=storege_context, embed_model=embed_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3310731293.py in <cell line: 0>()
# ----> 1 index = VectorStoreIndex.from_documents(documents, storage_context=storege_context, embed_model=embed_model)
#
# NameError: name 'storege_context' is not defined
